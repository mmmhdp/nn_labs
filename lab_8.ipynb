# %%
import torch as tr
from torch import nn
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import ipdb
from torch.utils.data import Dataset, DataLoader
from datetime import datetime

# %%
# !pip install ipdb

# %%
import string

class CaesarDataset(Dataset):
    def __init__(self, step, path_to_file):
        self.caesar_dict = self.generate_caesar_dictionary(step = step)
        self.stoi = self.generate_stoi()
        self.itos = self.generate_itos()
        self.dataset = self.generate_dataset(path_to_file = path_to_file)
        
    def __len__(self):
        return len(self.dataset["X"])
        
    def __getitem__(self, ix):
        return self.dataset["X"][ix], self.dataset["Y"][ix]
        
    def generate_caesar_dictionary(self, step :int) -> dict[str:str]:
        alphabet = list(string.ascii_lowercase)
        caesar_dict = {ch : alphabet[(ix + step)%len(alphabet)] for ix, ch in enumerate(alphabet)}
        return caesar_dict
            
    def word_to_caesar(self, word :str) -> str:
        encoded = [self.caesar_dict[ch] for ch in word]
        encoded = "".join(encoded)
        return encoded
    
    def generate_stoi(self):
        alphabet = list(string.ascii_lowercase)
        stoi = {ch : ix for ix, ch in enumerate(alphabet)}
        return stoi
        
    def generate_itos(self):
        alphabet = list(string.ascii_lowercase)
        itos = {ix : ch for ix, ch in enumerate(alphabet)}
        return itos
    
    def generate_dataset(self, path_to_file: str):
        dt = pd.read_csv(path_to_file)
        words_raw = dt['word'].to_numpy()
        words = list(words_raw[type(words_raw) != float].squeeze(0))[:]
        dataset = {"X":[], "Y":[]}
        
        for ix, word in enumerate(words):
            if word is not np.nan:
                x,y = self.word_to_caesar(word), word
                for ch in x:
                    dataset["X"].append(self.stoi[ch])
                for ch in y:
                    dataset["Y"].append(self.stoi[ch])
                    
        dataset["X"] = tr.tensor(dataset["X"]).type(tr.float32).view(-1,1)
        dataset["Y"] = tr.tensor(dataset["Y"]).type(tr.long)
        return dataset

caesar_dataset = CaesarDataset(
    step = 2,
    path_to_file="/kaggle/input/unigram-freq-for-lstm/unigram_freq.csv"
        )

train_amount = 0.7
val_amount = 0.5

trainn = int(len(caesar_dataset) * train_amount) 
valn = int((len(caesar_dataset) - trainn) * val_amount)
testn = len(caesar_dataset) - trainn - valn
train_data, val_data, test_data = tr.utils.data.random_split(caesar_dataset, [trainn, valn, testn])

train : DataLoader = DataLoader(train_data, batch_size = 16, shuffle = True)
val : DataLoader = DataLoader(val_data, batch_size = 16, shuffle = True)
test : DataLoader = DataLoader(test_data, batch_size = 16, shuffle = False)

# %%
class Trainer:
    def __init__(
        self,
        model,
        lossf, 
        opt,
        sch,
        epochn,
        device,
        train_dataloader,
        val_dataloader,
        test_dataloader
    ):
        self.model = model
        self.lossf = lossf
        self.opt = opt
        self.sch = sch
        self.epochn = epochn
        self.device = device
        self.train_dataloader = train_dataloader
        self.val_dataloader = val_dataloader
        self.test_dataloader = test_dataloader
        
        self.lossi = []
        self.val_lossi = []
        self.test_lossi = []
        
    def train(self):
        model.to(self.device)

        for epoch in range(self.epochn):
            model.train()

            print("-"*80)
            print("| Epoch: %d |" %epoch)
            print(f"|*TRAIN*|")
            model.to(self.device)
            self.training_step()
            self.sch.step()
            
            model.eval()
            print(f"|*VALIDATION*|")
            self.validate()
            
        print("-"*80)
        print("-"*80)
        print("-"*80)
        print(f"|*TEST*|")
        model.eval()
        self.test()
    
    def training_step(self):
        local_loss = []
        infon = 5000
        b_ts = datetime.now()
        for ix, (features, target) in enumerate(self.train_dataloader):
            opt.zero_grad()
            
            features = features.to(self.device)
            pred = self.model(features)
            target = target.to(self.device)
            
            loss = lossf(pred, target)
            loss.backward()
            opt.step()

            self.lossi.append(loss.item())
            local_loss.append(loss.item())
            
            if ix % infon == 0 and ix != 0:
                local_loss = tr.tensor(local_loss)
                e_ts = datetime.now()
            
                print(f"| train time of {infon} batches: {e_ts - b_ts} |")
                print(f"| total train batch mean loss: {tr.mean(local_loss)} |")
                local_loss = []
                b_ts = e_ts

    
    def validate(self):
        local_loss = []
        b_ts = datetime.now()
                
        with tr.no_grad():
            for ix, (features, target) in enumerate(self.val_dataloader):
                features = features.to(self.device)
                pred = self.model(features)
                target = target.to(self.device)
                
                loss = lossf(pred, target)
                self.val_lossi.append(loss)
                local_loss.append(loss)
        local_loss = tr.tensor(local_loss)
        e_ts = datetime.now()
        print(f"| val time: {e_ts - b_ts}|")
        print(f"| val mean loss: {tr.mean(local_loss)} |")
    
            
    def test(self):
        b_ts = datetime.now()
        with tr.no_grad():
            for ix, (features, target) in enumerate(self.test_dataloader):
                features = features.to(self.device)
                pred = self.model(features)
                target = target.to(self.device)
                
                loss = lossf(pred, target)

                self.test_lossi.append(loss)
                
        local_loss = tr.tensor(self.test_lossi)
        e_ts = datetime.now()
        print(f"test time: {e_ts - b_ts}")
        print(f"| test mean loss: {tr.mean(local_loss)} |")
                
    def get_metadata(self):
        return self.lossi, self.val_lossi, self.test_lossi

# %%
class LSTMClassifier(nn.Module):
    def __init__(self, classn, embsize, innern = 16):
        super().__init__()
        self.embsize = embsize
        self.innern = innern
        self.classn = classn
        
        self.inp = nn.Linear(embsize, innern)
        self.sig = nn.Sigmoid()
        self.tanh = nn.Tanh()

        self.i_t_sub_lin_x_t = nn.Linear(innern, innern)
        self.i_t_sub_lin_h_t = nn.Linear(innern, innern)
        
        self.f_t_sub_lin_x_t = nn.Linear(innern, innern)
        self.f_t_sub_lin_h_t = nn.Linear(innern, innern)
        
        self.g_t_sub_lin_x_t = nn.Linear(innern, innern)
        self.g_t_sub_lin_h_t = nn.Linear(innern, innern)
        
        self.o_t_sub_lin_x_t = nn.Linear(innern, innern)
        self.o_t_sub_lin_h_t = nn.Linear(innern, innern)

        
        self.out = nn.Linear(innern, classn)
        self.sf = nn.Softmax(dim = 1)
        
        self.c_t = nn.Parameter(tr.randn(innern, innern)) # init for "long" memory
        self.h_t = nn.Parameter(tr.randn(innern, innern)) # init for previous step result
    
    def forward(self, X):
        out_states = []
        for ix in range(X.shape[0]):
            x = X[ix]
            
            in_l = self.inp(x)
            
            i_t = self.sig(
                self.i_t_sub_lin_x_t(in_l) + self.i_t_sub_lin_x_t(self.h_t)
            ) #input
            
            f_t = self.sig(
                self.f_t_sub_lin_x_t(in_l) + self.f_t_sub_lin_x_t(self.h_t)
            ) #forget
            
            g_t = self.tanh(
                self.g_t_sub_lin_x_t(in_l) + self.g_t_sub_lin_x_t(self.h_t)
            ) #cell gate
            
            o_t = self.sig(
                self.o_t_sub_lin_x_t(in_l) + self.o_t_sub_lin_x_t(self.h_t)
            ) #output gate
            
            c_t = tr.mul(f_t, self.c_t) + tr.mul(i_t, g_t) #cell state 
            h_t = tr.mul(o_t, self.tanh(self.c_t)) #hidden state
            
            sub_out = self.out(h_t)
            sub_out = sub_out.mean(dim=0)
            out_states.append(sub_out)
        
        out_raw = tr.stack(out_states)
        out = self.sf(out_raw)
        return out

classn = len(caesar_dataset.caesar_dict)
emb_size = 1
fan_in, fan_out = emb_size, classn
LSTM = LSTMClassifier(
    classn = classn,
    embsize = 1,
)

# %%
model = LSTM
epochn = 500_000
lr = 1e-4

lossf = nn.CrossEntropyLoss()
opt = tr.optim.RMSprop(model.parameters(), lr = lr)
sch = tr.optim.lr_scheduler.CosineAnnealingWarmRestarts(optimizer=opt, T_0=10)

device = tr.device("cuda") if tr.cuda.is_available() else tr.device("cpu")

train_dataloader = train 
val_dataloader = val
test_dataloader =test


config = {
    "model":model,
    "lossf":lossf,
    "opt":opt,
    "sch":sch,
    "epochn":epochn,
    "device":device,
    "train_dataloader":train_dataloader,
    "val_dataloader":val_dataloader,
    "test_dataloader":test_dataloader,
}
         
trainer = Trainer(**config)
trainer.train()
tr.save(model, f"/kaggle/working/{datetime.now()}")
# Out:
# --------------------------------------------------------------------------------
# | Epoch: 0 |
# |*TRAIN*|
# | train time of 5000 batches: 0:01:35.471283 |
# | total train batch mean loss: 3.235217332839966 |
# | train time of 5000 batches: 0:01:35.414004 |
# | total train batch mean loss: 3.1514432430267334 |
# | train time of 5000 batches: 0:01:34.990467 |
# | total train batch mean loss: 3.0833723545074463 |
# | train time of 5000 batches: 0:01:35.186079 |
# | total train batch mean loss: 3.0365726947784424 |
# | train time of 5000 batches: 0:01:34.991591 |
# | total train batch mean loss: 3.0011348724365234 |
# | train time of 5000 batches: 0:01:35.211563 |
# | total train batch mean loss: 2.981088638305664 |
# | train time of 5000 batches: 0:01:35.361099 |
# | total train batch mean loss: 2.966353416442871 |
# | train time of 5000 batches: 0:01:35.335022 |
# | total train batch mean loss: 2.95896053314209 |
# | train time of 5000 batches: 0:01:35.145869 |
# | total train batch mean loss: 2.940673351287842 |
# | train time of 5000 batches: 0:01:34.950453 |
# | total train batch mean loss: 2.8987202644348145 |
# | train time of 5000 batches: 0:01:35.189524 |
# | total train batch mean loss: 2.877082109451294 |
# | train time of 5000 batches: 0:01:35.101373 |
# | total train batch mean loss: 2.861011505126953 |
# | train time of 5000 batches: 0:01:35.052858 |
# | total train batch mean loss: 2.84263277053833 |
# | train time of 5000 batches: 0:01:35.289459 |
# | total train batch mean loss: 2.828296184539795 |
# | train time of 5000 batches: 0:01:35.848878 |
# | total train batch mean loss: 2.820035457611084 |
# | train time of 5000 batches: 0:01:36.726345 |
# | total train batch mean loss: 2.805116653442383 |
# | train time of 5000 batches: 0:01:35.744616 |
# | total train batch mean loss: 2.7904748916625977 |
# | train time of 5000 batches: 0:01:34.144247 |
# | total train batch mean loss: 2.7814197540283203 |
# | train time of 5000 batches: 0:01:34.819079 |
# | total train batch mean loss: 2.7611427307128906 |
# | train time of 5000 batches: 0:01:34.709379 |
# | total train batch mean loss: 2.746300458908081 |
# | train time of 5000 batches: 0:01:34.778796 |
# | total train batch mean loss: 2.7441561222076416 |
# |*VALIDATION*|
# | val time: 0:03:32.076580|
# | val mean loss: 2.7370738983154297 |
# --------------------------------------------------------------------------------
# | Epoch: 1 |
# |*TRAIN*|
# | train time of 5000 batches: 0:01:37.916575 |
# | total train batch mean loss: 2.7331583499908447 |
# | train time of 5000 batches: 0:01:37.100420 |
# | total train batch mean loss: 2.7310779094696045 |
# | train time of 5000 batches: 0:01:37.313758 |
# | total train batch mean loss: 2.720977544784546 |
# | train time of 5000 batches: 0:01:37.685803 |
# | total train batch mean loss: 2.7149744033813477 |
# | train time of 5000 batches: 0:01:37.022428 |
# | total train batch mean loss: 2.714003562927246 |
# | train time of 5000 batches: 0:01:37.184875 |
# | total train batch mean loss: 2.711458683013916 |
# | train time of 5000 batches: 0:01:36.942260 |
# | total train batch mean loss: 2.703641891479492 |
# | train time of 5000 batches: 0:01:37.579815 |
# | total train batch mean loss: 2.7023823261260986 |
# | train time of 5000 batches: 0:01:37.659066 |
# | total train batch mean loss: 2.6961312294006348 |
# | train time of 5000 batches: 0:01:37.192559 |
# | total train batch mean loss: 2.6882855892181396 |
# | train time of 5000 batches: 0:01:36.980020 |
# | total train batch mean loss: 2.686760187149048 |
# | train time of 5000 batches: 0:01:37.087904 |
# | total train batch mean loss: 2.673369884490967 |
# | train time of 5000 batches: 0:01:37.358638 |
# | total train batch mean loss: 2.663083791732788 |
# | train time of 5000 batches: 0:01:37.057398 |
# | total train batch mean loss: 2.663022518157959 |
# | train time of 5000 batches: 0:01:37.262634 |
# | total train batch mean loss: 2.657846212387085 |
# | train time of 5000 batches: 0:01:37.349153 |
# | total train batch mean loss: 2.6560282707214355 |
# | train time of 5000 batches: 0:01:37.249332 |
# | total train batch mean loss: 2.654048204421997 |
# | train time of 5000 batches: 0:01:37.303421 |
# | total train batch mean loss: 2.651512384414673 |
# | train time of 5000 batches: 0:01:38.578694 |
# | total train batch mean loss: 2.650827646255493 |
# | train time of 5000 batches: 0:01:37.704684 |
# | total train batch mean loss: 2.6465179920196533 |
# | train time of 5000 batches: 0:01:37.706849 |
# | total train batch mean loss: 2.6480917930603027 |
# |*VALIDATION*|
# | val time: 0:03:35.987545|
# | val mean loss: 2.645669460296631 |
# --------------------------------------------------------------------------------
# | Epoch: 2 |
# |*TRAIN*|
# | train time of 5000 batches: 0:01:39.776865 |
# | total train batch mean loss: 2.6451501846313477 |
# | train time of 5000 batches: 0:01:39.776951 |
# | total train batch mean loss: 2.6443142890930176 |
# | train time of 5000 batches: 0:01:39.911113 |
# | total train batch mean loss: 2.6439874172210693 |
# | train time of 5000 batches: 0:01:39.920976 |
# | total train batch mean loss: 2.643932342529297 |
# | train time of 5000 batches: 0:01:40.197166 |
# | total train batch mean loss: 2.640991687774658 |
# | train time of 5000 batches: 0:01:40.101570 |
# | total train batch mean loss: 2.639575481414795 |
# | train time of 5000 batches: 0:01:39.686369 |
# | total train batch mean loss: 2.641197443008423 |
# | train time of 5000 batches: 0:01:40.250696 |
# | total train batch mean loss: 2.637625217437744 |
# | train time of 5000 batches: 0:01:40.018123 |
# | total train batch mean loss: 2.642735481262207 |
# | train time of 5000 batches: 0:01:39.891098 |
# | total train batch mean loss: 2.637786388397217 |
# | train time of 5000 batches: 0:01:39.540401 |
# | total train batch mean loss: 2.6376450061798096 |
# | train time of 5000 batches: 0:01:39.302910 |
# | total train batch mean loss: 2.6355576515197754 |
# | train time of 5000 batches: 0:01:39.921635 |
# | total train batch mean loss: 2.628359794616699 |
# | train time of 5000 batches: 0:01:39.352559 |
# | total train batch mean loss: 2.6284823417663574 |
# | train time of 5000 batches: 0:01:39.862604 |
# | total train batch mean loss: 2.630784034729004 |
# | train time of 5000 batches: 0:01:39.178071 |
# | total train batch mean loss: 2.631028890609741 |
# | train time of 5000 batches: 0:01:38.843163 |
# | total train batch mean loss: 2.6306424140930176 |
# | train time of 5000 batches: 0:01:38.579328 |
# | total train batch mean loss: 2.6295039653778076 |
# | train time of 5000 batches: 0:01:38.697838 |
# | total train batch mean loss: 2.6312413215637207 |
# | train time of 5000 batches: 0:01:38.811672 |
# | total train batch mean loss: 2.6274914741516113 |
# | train time of 5000 batches: 0:01:38.708918 |
# | total train batch mean loss: 2.6266374588012695 |
# |*VALIDATION*|
# | val time: 0:03:34.677673|
# | val mean loss: 2.627962589263916 |
# --------------------------------------------------------------------------------
# | Epoch: 3 |
# |*TRAIN*|
# | train time of 5000 batches: 0:01:39.432404 |
# | total train batch mean loss: 2.6304173469543457 |
# | train time of 5000 batches: 0:01:38.893095 |
# | total train batch mean loss: 2.6269915103912354 |
# | train time of 5000 batches: 0:01:38.962739 |
# | total train batch mean loss: 2.6240146160125732 |
# | train time of 5000 batches: 0:01:40.016374 |
# | total train batch mean loss: 2.628199577331543 |
# | train time of 5000 batches: 0:01:39.361590 |
# | total train batch mean loss: 2.6287198066711426 |
# | train time of 5000 batches: 0:01:39.811911 |
# | total train batch mean loss: 2.6239821910858154 |
# | train time of 5000 batches: 0:01:39.816115 |
# | total train batch mean loss: 2.6269619464874268 |
# | train time of 5000 batches: 0:01:40.025426 |
# | total train batch mean loss: 2.625131130218506 |
# | train time of 5000 batches: 0:01:40.383817 |
# | total train batch mean loss: 2.624221086502075 |
# | train time of 5000 batches: 0:01:40.379341 |
# | total train batch mean loss: 2.6248209476470947 |
# | train time of 5000 batches: 0:01:40.412950 |
# | total train batch mean loss: 2.6266911029815674 |
# | train time of 5000 batches: 0:01:41.441100 |
# | total train batch mean loss: 2.626251459121704 |
# | train time of 5000 batches: 0:01:40.411302 |
# | total train batch mean loss: 2.624128818511963 |
# | train time of 5000 batches: 0:01:40.513171 |
# | total train batch mean loss: 2.623762845993042 |
# | train time of 5000 batches: 0:01:40.304548 |
# | total train batch mean loss: 2.6263725757598877 |
# | train time of 5000 batches: 0:01:40.698047 |
# | total train batch mean loss: 2.6243464946746826 |
# | train time of 5000 batches: 0:01:41.107595 |
# | total train batch mean loss: 2.6257452964782715 |
# | train time of 5000 batches: 0:01:40.725670 |
# | total train batch mean loss: 2.624882936477661 |
# | train time of 5000 batches: 0:01:40.715307 |
# | total train batch mean loss: 2.6240737438201904 |
# | train time of 5000 batches: 0:01:40.292654 |
# | total train batch mean loss: 2.625072956085205 |
# | train time of 5000 batches: 0:01:40.954096 |
# | total train batch mean loss: 2.623943328857422 |
# |*VALIDATION*|
# | val time: 0:03:37.024860|
# | val mean loss: 2.62398624420166 |
# --------------------------------------------------------------------------------
# | Epoch: 4 |
# |*TRAIN*|
# | train time of 5000 batches: 0:01:39.396946 |
# | total train batch mean loss: 2.622972011566162 |
# | train time of 5000 batches: 0:01:39.790144 |
# | total train batch mean loss: 2.6241302490234375 |
# | train time of 5000 batches: 0:01:43.283408 |
# | total train batch mean loss: 2.6249184608459473 |
# | train time of 5000 batches: 0:01:40.517766 |
# | total train batch mean loss: 2.6233229637145996 |
# | train time of 5000 batches: 0:01:40.864370 |
# | total train batch mean loss: 2.6241812705993652 |
# | train time of 5000 batches: 0:01:41.609264 |
# | total train batch mean loss: 2.623690128326416 |
# | train time of 5000 batches: 0:01:40.203972 |
# | total train batch mean loss: 2.62520432472229 |
# | train time of 5000 batches: 0:01:40.421103 |
# | total train batch mean loss: 2.6248581409454346 |
# | train time of 5000 batches: 0:01:40.337103 |
# | total train batch mean loss: 2.623849391937256 |
# | train time of 5000 batches: 0:01:40.303023 |
# | total train batch mean loss: 2.621943712234497 |
# | train time of 5000 batches: 0:01:40.523913 |
# | total train batch mean loss: 2.620966911315918 |
# | train time of 5000 batches: 0:01:40.258629 |
# | total train batch mean loss: 2.6213934421539307 |
# | train time of 5000 batches: 0:01:40.025785 |
# | total train batch mean loss: 2.624569892883301 |
# | train time of 5000 batches: 0:01:39.258681 |
# | total train batch mean loss: 2.623328685760498 |
# | train time of 5000 batches: 0:01:40.225859 |
# | total train batch mean loss: 2.6219193935394287 |
# | train time of 5000 batches: 0:01:39.940774 |
# | total train batch mean loss: 2.62322735786438 |
# | train time of 5000 batches: 0:01:39.755214 |
# | total train batch mean loss: 2.6232237815856934 |
# | train time of 5000 batches: 0:01:40.579567 |
# | total train batch mean loss: 2.622450828552246 |
# | train time of 5000 batches: 0:01:40.370326 |
# | total train batch mean loss: 2.6206607818603516 |
# | train time of 5000 batches: 0:01:39.551324 |
# | total train batch mean loss: 2.6217381954193115 |
# | train time of 5000 batches: 0:01:39.660485 |
# | total train batch mean loss: 2.6226491928100586 |
# |*VALIDATION*|
# | val time: 0:03:35.815367|
# | val mean loss: 2.6225054264068604 |
# --------------------------------------------------------------------------------
# | Epoch: 5 |
# |*TRAIN*|
# | train time of 5000 batches: 0:01:40.587023 |
# | total train batch mean loss: 2.619422674179077 |
# | train time of 5000 batches: 0:01:40.111135 |
# | total train batch mean loss: 2.6222102642059326 |
# | train time of 5000 batches: 0:01:40.845910 |
# | total train batch mean loss: 2.6226179599761963 |
# | train time of 5000 batches: 0:01:40.433587 |
# | total train batch mean loss: 2.623541831970215 |
# | train time of 5000 batches: 0:01:40.703983 |
# | total train batch mean loss: 2.6236588954925537 |
# | train time of 5000 batches: 0:01:40.636507 |
# | total train batch mean loss: 2.6253159046173096 |
# | train time of 5000 batches: 0:01:40.156202 |
# | total train batch mean loss: 2.6221163272857666 |
# | train time of 5000 batches: 0:01:40.161443 |
# | total train batch mean loss: 2.6220600605010986 |
# | train time of 5000 batches: 0:01:40.571367 |
# | total train batch mean loss: 2.621260643005371 |
# | train time of 5000 batches: 0:01:40.694075 |
# | total train batch mean loss: 2.6205687522888184 |
# | train time of 5000 batches: 0:01:41.425433 |
# | total train batch mean loss: 2.6215460300445557 |
# | train time of 5000 batches: 0:01:40.710574 |
# | total train batch mean loss: 2.62215518951416 |
# | train time of 5000 batches: 0:01:41.537539 |
# | total train batch mean loss: 2.6198556423187256 |
# | train time of 5000 batches: 0:01:40.365649 |
# | total train batch mean loss: 2.621640920639038 |
# | train time of 5000 batches: 0:01:40.793163 |
# | total train batch mean loss: 2.6211097240448 |
# | train time of 5000 batches: 0:01:40.364388 |
# | total train batch mean loss: 2.6219518184661865 |
# | train time of 5000 batches: 0:01:40.497847 |
# | total train batch mean loss: 2.6213438510894775 |
# | train time of 5000 batches: 0:01:40.580175 |
# | total train batch mean loss: 2.62335205078125 |
# | train time of 5000 batches: 0:01:40.577998 |
# | total train batch mean loss: 2.6220619678497314 |
# | train time of 5000 batches: 0:01:40.282214 |
# | total train batch mean loss: 2.6203699111938477 |
# | train time of 5000 batches: 0:01:39.939007 |
# | total train batch mean loss: 2.623739004135132 |
# |*VALIDATION*|
# | val time: 0:03:37.179533|
# | val mean loss: 2.621765613555908 |
# --------------------------------------------------------------------------------
# | Epoch: 6 |
# |*TRAIN*|
# | train time of 5000 batches: 0:01:40.091856 |
# | total train batch mean loss: 2.6200971603393555 |
# | train time of 5000 batches: 0:01:39.820392 |
# | total train batch mean loss: 2.6240427494049072 |
# | train time of 5000 batches: 0:01:39.040331 |
# | total train batch mean loss: 2.6230030059814453 |
# | train time of 5000 batches: 0:01:39.437671 |
# | total train batch mean loss: 2.6222503185272217 |
# | train time of 5000 batches: 0:01:40.434226 |
# | total train batch mean loss: 2.621763229370117 |
# | train time of 5000 batches: 0:01:39.370705 |
# | total train batch mean loss: 2.6208629608154297 |
# | train time of 5000 batches: 0:01:39.466684 |
# | total train batch mean loss: 2.6230826377868652 |
# | train time of 5000 batches: 0:01:39.911375 |
# | total train batch mean loss: 2.623427391052246 |
# | train time of 5000 batches: 0:01:39.803173 |
# | total train batch mean loss: 2.621901512145996 |
# | train time of 5000 batches: 0:01:39.826937 |
# | total train batch mean loss: 2.6210968494415283 |
# | train time of 5000 batches: 0:01:38.937254 |
# | total train batch mean loss: 2.619410514831543 |
# | train time of 5000 batches: 0:01:40.575089 |
# | total train batch mean loss: 2.620698928833008 |
# | train time of 5000 batches: 0:01:39.844662 |
# | total train batch mean loss: 2.6227316856384277 |
# | train time of 5000 batches: 0:01:39.603521 |
# | total train batch mean loss: 2.620755434036255 |
# | train time of 5000 batches: 0:01:39.910353 |
# | total train batch mean loss: 2.6216015815734863 |
# | train time of 5000 batches: 0:01:39.515000 |
# | total train batch mean loss: 2.621365547180176 |
# | train time of 5000 batches: 0:01:39.226905 |
# | total train batch mean loss: 2.620867967605591 |
# | train time of 5000 batches: 0:01:40.678117 |
# | total train batch mean loss: 2.6193032264709473 |
# | train time of 5000 batches: 0:01:39.002682 |
# | total train batch mean loss: 2.620753526687622 |
# | train time of 5000 batches: 0:01:39.526582 |
# | total train batch mean loss: 2.6205270290374756 |
# | train time of 5000 batches: 0:01:39.618335 |
# | total train batch mean loss: 2.619795083999634 |
# |*VALIDATION*|
# | val time: 0:03:37.353295|
# | val mean loss: 2.6211159229278564 |
# --------------------------------------------------------------------------------
# | Epoch: 7 |
# |*TRAIN*|
# | train time of 5000 batches: 0:01:39.856869 |
# | total train batch mean loss: 2.621311902999878 |
# | train time of 5000 batches: 0:01:39.569023 |
# | total train batch mean loss: 2.6189310550689697 |
# | train time of 5000 batches: 0:01:40.150733 |
# | total train batch mean loss: 2.621229410171509 |
# | train time of 5000 batches: 0:01:39.414513 |
# | total train batch mean loss: 2.6197376251220703 |
# | train time of 5000 batches: 0:01:39.780547 |
# | total train batch mean loss: 2.623851776123047 |
# | train time of 5000 batches: 0:01:40.077129 |
# | total train batch mean loss: 2.620718240737915 |
# | train time of 5000 batches: 0:01:40.310046 |
# | total train batch mean loss: 2.623826265335083 |
# | train time of 5000 batches: 0:01:39.440660 |
# | total train batch mean loss: 2.6204395294189453 |
# | train time of 5000 batches: 0:01:39.291275 |
# | total train batch mean loss: 2.6202077865600586 |
# | train time of 5000 batches: 0:01:39.211672 |
# | total train batch mean loss: 2.6212942600250244 |
# | train time of 5000 batches: 0:01:39.840891 |
# | total train batch mean loss: 2.619368553161621 |
# | train time of 5000 batches: 0:01:39.406668 |
# | total train batch mean loss: 2.621065855026245 |
# | train time of 5000 batches: 0:01:39.929785 |
# | total train batch mean loss: 2.622019052505493 |
# | train time of 5000 batches: 0:01:40.557303 |
# | total train batch mean loss: 2.619809865951538 |
# | train time of 5000 batches: 0:01:39.781772 |
# | total train batch mean loss: 2.6214826107025146 |
# | train time of 5000 batches: 0:01:40.953140 |
# | total train batch mean loss: 2.6202304363250732 |
# | train time of 5000 batches: 0:01:40.391206 |
# | total train batch mean loss: 2.616466760635376 |
# | train time of 5000 batches: 0:01:39.961065 |
# | total train batch mean loss: 2.618640661239624 |
# | train time of 5000 batches: 0:01:39.761078 |
# | total train batch mean loss: 2.613325357437134 |
# | train time of 5000 batches: 0:01:39.356023 |
# | total train batch mean loss: 2.6109261512756348 |
# | train time of 5000 batches: 0:01:40.080229 |
# | total train batch mean loss: 2.612128257751465 |
# |*VALIDATION*|
# | val time: 0:03:37.140299|
# | val mean loss: 2.610328197479248 |
# --------------------------------------------------------------------------------
# | Epoch: 8 |
# |*TRAIN*|
# | train time of 5000 batches: 0:01:40.007939 |
# | total train batch mean loss: 2.611649513244629 |
# | train time of 5000 batches: 0:01:39.949610 |
# | total train batch mean loss: 2.6080706119537354 |
# | train time of 5000 batches: 0:01:41.043829 |
# | total train batch mean loss: 2.6113955974578857 |
# | train time of 5000 batches: 0:01:40.317767 |
# | total train batch mean loss: 2.6099298000335693 |
# | train time of 5000 batches: 0:01:40.195847 |
# | total train batch mean loss: 2.60909104347229 |
# | train time of 5000 batches: 0:01:40.336252 |
# | total train batch mean loss: 2.607433319091797 |
# | train time of 5000 batches: 0:01:40.186114 |
# | total train batch mean loss: 2.609259605407715 |
# | train time of 5000 batches: 0:01:41.276287 |
# | total train batch mean loss: 2.6091148853302 |
# | train time of 5000 batches: 0:01:40.368086 |
# | total train batch mean loss: 2.6085004806518555 |
# | train time of 5000 batches: 0:01:41.604991 |
# | total train batch mean loss: 2.607616901397705 |
# | train time of 5000 batches: 0:01:40.828692 |
# | total train batch mean loss: 2.6088311672210693 |
# | train time of 5000 batches: 0:01:40.403632 |
# | total train batch mean loss: 2.606920003890991 |
# | train time of 5000 batches: 0:01:39.983965 |
# | total train batch mean loss: 2.6102166175842285 |
# | train time of 5000 batches: 0:01:39.692908 |
# | total train batch mean loss: 2.6096746921539307 |
# | train time of 5000 batches: 0:01:41.512600 |
# | total train batch mean loss: 2.607758045196533 |
# | train time of 5000 batches: 0:01:40.861868 |
# | total train batch mean loss: 2.6088438034057617 |
# | train time of 5000 batches: 0:01:40.875291 |
# | total train batch mean loss: 2.6102728843688965 |
# | train time of 5000 batches: 0:01:40.867890 |
# | total train batch mean loss: 2.608701467514038 |
# | train time of 5000 batches: 0:01:41.473948 |
# | total train batch mean loss: 2.608624219894409 |
# | train time of 5000 batches: 0:01:40.294587 |
# | total train batch mean loss: 2.608309268951416 |
# | train time of 5000 batches: 0:01:41.155751 |
# | total train batch mean loss: 2.609834671020508 |
# |*VALIDATION*|
# | val time: 0:03:38.187955|
# | val mean loss: 2.6091063022613525 |
# --------------------------------------------------------------------------------
# | Epoch: 9 |
# |*TRAIN*|
# | train time of 5000 batches: 0:01:39.904075 |
# | total train batch mean loss: 2.6080245971679688 |
# | train time of 5000 batches: 0:01:39.698283 |
# | total train batch mean loss: 2.607734441757202 |
# | train time of 5000 batches: 0:01:40.412529 |
# | total train batch mean loss: 2.6078081130981445 |
# | train time of 5000 batches: 0:01:39.980977 |
# | total train batch mean loss: 2.6073901653289795 |
# | train time of 5000 batches: 0:01:40.143836 |
# | total train batch mean loss: 2.608813524246216 |
# | train time of 5000 batches: 0:01:39.335750 |
# | total train batch mean loss: 2.6069302558898926 |
# | train time of 5000 batches: 0:01:40.666215 |
# | total train batch mean loss: 2.6100306510925293 |
# | train time of 5000 batches: 0:01:40.102617 |
# | total train batch mean loss: 2.6103217601776123 |
# | train time of 5000 batches: 0:01:40.136645 |
# | total train batch mean loss: 2.609766721725464 |
# | train time of 5000 batches: 0:01:39.079619 |
# | total train batch mean loss: 2.609914779663086 |
# | train time of 5000 batches: 0:01:39.466359 |
# | total train batch mean loss: 2.607815980911255 |
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 29
#      16 config = {
#      17     "model":model,
#      18     "lossf":lossf,
#    (...)
#      25     "test_dataloader":test_dataloader,
#      26 }
#      28 trainer = Trainer(**config)
# ---> 29 trainer.train()
#      30 tr.save(model, f"/kaggle/working/{datetime.now()}")
#
# Cell In[4], line 38, in Trainer.train(self)
#      36 print(f"|*TRAIN*|")
#      37 model.to(self.device)
# ---> 38 self.training_step()
#      39 self.sch.step()
#      41 model.eval()
#
# Cell In[4], line 64, in Trainer.training_step(self)
#      61 target = target.to(self.device)
#      63 loss = lossf(pred, target)
# ---> 64 loss.backward()
#      65 opt.step()
#      67 self.lossi.append(loss.item())
#
# File /opt/conda/lib/python3.10/site-packages/torch/_tensor.py:492, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     482 if has_torch_function_unary(self):
#     483     return handle_torch_function(
#     484         Tensor.backward,
#     485         (self,),
#    (...)
#     490         inputs=inputs,
#     491     )
# --> 492 torch.autograd.backward(
#     493     self, gradient, retain_graph, create_graph, inputs=inputs
#     494 )
#
# File /opt/conda/lib/python3.10/site-packages/torch/autograd/__init__.py:251, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     246     retain_graph = create_graph
#     248 # The reason we repeat the same comment below is that
#     249 # some Python versions print out the first line of a multi-line function
#     250 # calls in the traceback and some print out the last line
# --> 251 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     252     tensors,
#     253     grad_tensors_,
#     254     retain_graph,
#     255     create_graph,
#     256     inputs,
#     257     allow_unreachable=True,
#     258     accumulate_grad=True,
#     259 )
#
# KeyboardInterrupt:

# %%
tr.save(model, f"/kaggle/working/{datetime.now()}")

# %%
trainer.test()
# Out:
# test time: 0:03:29.875237
# | test mean loss: 2.6082804203033447 |

# %%
lossi, val_lossi, test_lossi = trainer.get_metadata()
fig, ax = plt.subplots(1,3, figsize=(15,5))

def reduce_verbose(loss, aggr_step):
    sub_loss = []
    for ix in range(0, len(loss), aggr_step):
        sub_loss.append(tr.mean(loss[ix: ix + 10]).item())
    return tr.tensor(sub_loss)
    
LOSS = [lossi, val_lossi, test_lossi]
for ix, loss in enumerate(LOSS):
    LOSS[ix] = tr.tensor(loss)
    LOSS[ix] = tr.log(LOSS[ix])
    if loss.__class__.__name__!="test_lossi":
        LOSS[ix] = reduce_verbose(LOSS[ix], aggr_step=5000)
    else:
        LOSS[ix] = reduce_verbose(LOSS[ix], aggr_step=1)
ax[0].plot(LOSS[0])
ax[0].set_title("train loss")
ax[1].plot(LOSS[1])
ax[1].set_title("validation loss")
ax[2].plot(LOSS[2])
ax[2].set_title("test loss")
plt.show();

# %%
def predict_word(check):
    enc_check = tr.tensor([caesar_dataset.stoi[ch] for ch in check]).view(-1,1).type(tr.float32)
    enc_check = enc_check.to(device)
    raw_res = model(enc_check)
    model_word = []
    for ix in tr.max(raw_res, dim=1).indices:
        model_word.append(caesar_dataset.itos[ix.item()] )
    return "".join(model_word)

words = ["some", "staff", "hello", "auto", "hero", "reconstruction"]

def inference(words):
    print("INFERENCE:")
    print("-"*50)
    for word in words:
        enc  = caesar_dataset.word_to_caesar(word) 
        print("Encoded: " + enc)
        print("Meaning: " + word)
        print("Pred Meaning: " + predict_word(enc))
        print("*"*50)

inference(words)
# Out:
# INFERENCE:
# --------------------------------------------------
# Encoded: uqog
# Meaning: some
# Pred Meaning: role
# **************************************************
# Encoded: uvchh
# Meaning: staff
# Pred Meaning: rraff
# **************************************************
# Encoded: jgnnq
# Meaning: hello
# Pred Meaning: hello
# **************************************************
# Encoded: cwvq
# Meaning: auto
# Pred Meaning: arro
# **************************************************
# Encoded: jgtq
# Meaning: hero
# Pred Meaning: hero
# **************************************************
# Encoded: tgeqpuvtwevkqp
# Meaning: reconstruction
# Pred Meaning: reconrrrrcrion
# **************************************************
